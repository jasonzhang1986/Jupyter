# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
plt.plot(np.random.rand(10))
plt.show()

# %%
% matplotlib inline

s = pd.Series(np.random.rand(100))
s.plot(style='-',figsize=(10,5))

# %%
df = pd.DataFrame(np.random.rand(10,2), columns=['A','B'])
# print(df)
fig = df.plot(figsize=(10,5))
plt.title('Title')
plt.xlabel('Plot Number')
plt.ylabel('Important var')
plt.xlim([0,10])
plt.xticks(range(10))
plt.grid(True, linestyle = "--",color = "gray", linewidth = "0.5",axis = 'both')

# %%
plt.plot([i**2 for i in range(100)],
        linestyle='-.') 
#linestyle
# '-'       solid line style
# '--'      dashed line style
# '-.'      dash-dot line style
# ':'       dotted line style
plt.show()

# %%
s = pd.Series(np.random.randn(100).cumsum())
s.plot(linestyle='--', marker = '.',figsize=(10,5))

# %%
df = pd.DataFrame(np.random.randn(100,4), columns=list('ABCD'))
df = df.cumsum()
df.plot(linestyle='--', colormap='BrBG', figsize=(15,5))

# %%
t = np.arange(0.0,100.0,1)
s = np.sin(0.1*np.pi*t)*np.exp(-t*0.01)
plt.figure(figsize=(15,6)) #要先设置图表的大小
plt.plot(t,s,'--.')
plt.grid(True, linestyle='--', color='gray', linewidth='0.5', axis='both')

# %%
from matplotlib.ticker import MultipleLocator, FormatStrFormatter

t = np.arange(0.0,100.0,1)
s = np.sin(0.1*np.pi*t)*np.exp(-t*0.01)

f = plt.figure(figsize=(10,5))
ax = f.add_subplot(111)
plt.plot(t, s, '--.')

xmajorLocator = MultipleLocator(10)
xmajorFormatter = FormatStrFormatter('%.0f')
xminorLocator = MultipleLocator(5)

ymajorLocator = MultipleLocator(0.2)
ymajorFormatter = FormatStrFormatter('%.1f')
yminorLocator = MultipleLocator(0.1)

ax.xaxis.set_major_locator(xmajorLocator)
ax.xaxis.set_major_formatter(xmajorFormatter)
ax.xaxis.set_minor_locator(xminorLocator)

ax.yaxis.set_major_locator(ymajorLocator)
ax.yaxis.set_major_formatter(ymajorFormatter)
ax.yaxis.set_minor_locator(yminorLocator)


ax.xaxis.grid(True, which='both')
ax.yaxis.grid(True, which='both')

# %%
df = pd.DataFrame(np.random.rand(10,2), columns=list('AB'))
df.plot(style = '--o', grid=True)
plt.text(5, df['A'][5]+0.02, 'haha')
# Out:
# Text(5,0.919867,'haha')

# %%
ts = pd.Series(np.random.randn(1000).cumsum(), index=pd.date_range('1/1/2000', periods=1000))
ts.plot(style = '--g.',grid = True)

# %%
fig = plt.figure(figsize=(16,8))
ax1 = fig.add_subplot(2,2,1)
plt.plot(np.random.rand(50).cumsum(), 'k--')
plt.plot(np.random.randn(50).cumsum(),'k--')

ax2 = fig.add_subplot(2,2,2)
plt.hist(np.random.rand(50))
# s = pd.Series(np.random.rand(50))
# s.plot(kind='bar',color='k', grid=True)

ax4 = fig.add_subplot(2,2,4)
df = pd.DataFrame(np.random.rand(10,4), columns=list('ABCD'))
plt.plot(df, linestyle='--',marker='o')

# %%
df = pd.DataFrame(np.random.rand(10,4), columns=list('ABCD'))
df.plot(linestyle='--',marker='o', figsize=(20,8), subplots=True, layout=(2,2), grid=True)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11349fb00>,
# ...
#       dtype=object)

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2000', periods=1000))
ts = ts.cumsum()
ts.plot(kind='line',
       label='hehe',
       style='--g.',
       color='red',
       alpha=0.4,
       use_index=True,
       rot=45,
       grid=True,
       ylim=[-50,50],
       yticks = list(range(-50,50,10)),
       figsize=(8,4),
       title="test",
       legend=True)
plt.show()

# %%
df = pd.DataFrame(np.random.randn(1000, 4), index=ts.index, columns=list('ABCD'))
df = df.cumsum()
df.plot(kind='line',
       style = '--.',
       alpha = 0.8,
       use_index = True,
       rot = 45,
       grid = True,
       figsize = (8,4),
       title = 'test',
       legend = True,
       subplots = False,
       colormap = 'viridis')

# %%
#柱状图
fig, axes = plt.subplots(4,1, figsize=(10,14))
s = pd.Series(np.random.randint(1,10,16), index = list("abcdefghijklmnop"))
df = pd.DataFrame(np.random.rand(10,3), columns=['a','b','c'])

s.plot(kind='bar', color='k', grid=True, alpha=0.5, ax=axes[0])
df.plot(kind='bar', ax=axes[1], grid=True, colormap='Reds_r')
df.plot(kind='bar', ax=axes[2], grid=True, colormap="Blues_r", stacked=True)

#横向的柱状图，以下两种方式都可以
# df.plot.barh(ax=axes[3], grid=True, colormap="BuGn_r", stacked=True)
df.plot(kind='barh', ax=axes[3], grid=True, colormap="BuGn_r", stacked=True)

# %%
plt.figure(figsize=(10,4))
x = np.arange(10)
y1 = np.random.rand(10)
y2 = -np.random.rand(10)

plt.bar(x, y1, width=1, facecolor='yellowgreen', edgecolor='white',yerr=y1*0.1)
plt.bar(x, y2, width=1, facecolor='lightskyblue', edgecolor='white',yerr=y2*0.1)
# Out:
# <Container object of 10 artists>

# %%
#面积图

df = pd.DataFrame(np.random.rand(10,4), columns=['a','b','c','d'])
df.plot.area(colormap='Greens_r', alpha=0.5, figsize=(10,4))

# %%
x = np.linspace(0,1,500)
y1 = np.sin(4 * np.pi * x) * np.exp(-5 * x)
y2 = -np.sin(4 * np.pi * x) * np.exp(-5 * x)
# plt.figure(figsize=(10,3))
plt.grid(True)
plt.fill(x, y1, 'r', alpha=0.5, label = 'y1')
plt.fill(x, y2, 'g', alpha=0.5, label = 'y2')

# %%
s = pd.Series(np.random.rand(4), index = list('ABCD'), name='series')
print(s)
plt.axis('equal')
plt.pie(s,
       labels=s.index,
       autopct='%.2f%%',
       explode=[0.1,0,0,0],
       radius=1.5)
# 第一个参数：数据
# explode：指定每部分的偏移量
# labels：标签
# colors：颜色
# autopct：饼图上的数据标签显示方式
# pctdistance：每个饼切片的中心和通过autopct生成的文本开始之间的比例
# labeldistance：被画饼标记的直径,默认值：1.1
# shadow：阴影
# startangle：开始角度
# radius：半径
# frame：图框
# counterclock：指定指针方向，顺时针或者逆时针
# Out:
# A    0.703575
# B    0.292591
# C    0.824825
# D    0.248468
# Name: series, dtype: float64
# ([<matplotlib.patches.Wedge at 0x126840828>,
# ...
#  [Text(0.843165,1.53348,'A'),
#   Text(-1.39687,0.878218,'B'),
#   Text(-0.696427,-1.49582,'C'),
#   Text(1.53401,-0.607715,'D')],
#  [Text(0.481808,0.876277,'34.00%'),
#   Text(-0.761927,0.479028,'14.14%'),
#   Text(-0.379869,-0.815904,'39.86%'),
#   Text(0.836732,-0.331481,'12.01%')])
